# %%
import xarray as xr

# %%
xr.open_dataset('IBTrACS.ALL.v04r00.nc')
# Out:
# /home/idies/workspace/Storage/akhot/persistent/miniconda3/envs/ee/lib/python3.12/site-packages/xarray/coding/times.py:254: RuntimeWarning: invalid value encountered in cast
#   flat_num_dates_ns_int = (flat_num_dates * _NS_PER_TIME_DELTA[delta]).astype(
# <xarray.Dataset>
# Dimensions:           (storm: 13811, date_time: 360, quadrant: 4)
# Coordinates:
#     time              (storm, date_time) datetime64[ns] ...
#     lat               (storm, date_time) float32 ...
#     lon               (storm, date_time) float32 ...
# Dimensions without coordinates: storm, date_time, quadrant
# Data variables: (12/147)
#     numobs            (storm) float32 ...
#     sid               (storm) |S13 ...
#     season            (storm) float32 ...
#     number            (storm) int16 ...
#     basin             (storm, date_time) |S2 ...
#     subbasin          (storm, date_time) |S2 ...
#     ...                ...
#     reunion_gust      (storm, date_time) float32 ...
# ...
